# %%
import pandas as pd
import numpy as np
pd.options.mode.chained_assignment = None  # default='warn'
from IPython.display import HTML

# %%
df = pd.read_csv(r'data/processed_data.csv')

# %%
df.head(10)
# Out:
#    Unnamed: 0                                   user_id             song_id  \
# 0           0  fd50c4007b68a3737fe052d5a4f78ce8aa117f3d  SOBONKR12A58A7A7E0
# 1           1  c34670d9c1718361feb93068a853cead3c95b76a  SOBONKR12A58A7A7E0
# 2           2  c5006d9f41f68ccccbf5ee29212b6af494110c5e  SOBONKR12A58A7A7E0
# 3           3  e4332e11f4df6dd26673bb6b085e9a2bbdc9b8a5  SOBONKR12A58A7A7E0
# 4           4  baf2fe5885ab93fbbdb7fecc6691788e70afb6c8  SOBONKR12A58A7A7E0
# 5           5  f6e34f0a68d5ea1344511e33486f956de361db78  SOBONKR12A58A7A7E0
# 6           6  e326c4b9fe3659ec1dc3af53fd7e0893809dafbc  SOBONKR12A58A7A7E0
# 7           7  00f7c493ee64884998ea98d9f5bed87bc4a0afcf  SOBONKR12A58A7A7E0
# 8           8  daa9e7e53ae787ab4f1b5518b695198947d821a2  SOBONKR12A58A7A7E0
# 9           9  cd4321d8fd42ba44996e7f34c2f6404cf5884696  SOBONKR12A58A7A7E0
#
#    freq    artist_name         release
# 0     1  Dwight Yoakam  You're The One
# 1     1  Dwight Yoakam  You're The One
# 2     1  Dwight Yoakam  You're The One
# 3     2  Dwight Yoakam  You're The One
# 4     4  Dwight Yoakam  You're The One
# 5     1  Dwight Yoakam  You're The One
# 6    25  Dwight Yoakam  You're The One
# 7     5  Dwight Yoakam  You're The One
# 8     1  Dwight Yoakam  You're The One
# 9     1  Dwight Yoakam  You're The One

# %%
#recommendation engine for most popular/trending songs
def create_popularity_recommendation(new_df, user_id, song_id, n=10):
    new_df_grouped = new_df.groupby([song_id]).agg({user_id: 'count'}).reset_index()
    new_df_grouped.rename(columns = {user_id: 'score'},inplace=True)
    
    #Sort the songs based upon recommendation score
    new_df_sort = new_df_grouped.sort_values(['score', song_id], ascending = [0,1])
    
    #Generate a recommendation rank based upon score
    new_df_sort['Rank'] = new_df_sort.score.rank(ascending=0, method='first')
        
    #Get the top n recommendations
    popularity_recommendations = new_df_sort.head(n)
    return list(popularity_recommendations.release)

# %%
create_popularity_recommendation(df,'artist_name','release')
# Out:
# ['Sehr kosmisch',
#  'Undo',
#  "You're The One",
#  'Dog Days Are Over (Radio Edit)',
#  'Revelry',
#  'Secrets',
#  'Horn Concerto No. 4 in E flat K495: II. Romance (Andante cantabile)',
#  'Hey_ Soul Sister',
#  'Fireflies',
#  'Tive Sim']
